# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../results/selected_deaths/summaries/popsize_1000_ns_1_dominance_0.5.csv')

# %%
#filter count > 20 
df = df[df['count'] > 20]

# %%
df
df.to_csv('test1.csv', index=True)

# %%
#plot of distribution of counts 
plt.figure(figsize=(10, 6))
sns.histplot(np.log10(df['count']), bins=20)
plt.title('Distribution of log10 counts')
# Out:
# Text(0.5, 1.0, 'Distribution of log10 counts')

# %%
df = pd.read_csv('../results/selected_deaths/summaries/mean_results.csv')

# %%
df['ns'] = df['n'] * df['s']

# %%
df['selective_deaths'] = df['mean_n_het']*df['h']*df['s']+df['mean_n_homo']*df['s']

# %%
df
# Out:
#      Unnamed: 0     n    s    h  mean_count_s_h     mean_t   mean_count  \
# 0             0  1000  0.0  0.0        0.000000  16.696437  4107.259977
# 1             1  1000  0.0  0.1        0.000000  16.614625  4078.783504
# 2             2  1000  0.0  0.2        0.000000  16.431783  3898.380607
# 3             3  1000  0.0  0.3        0.000000  16.475365  3976.184014
# 4             4  1000  0.0  0.4        0.000000  16.377433  3848.387067
# ..          ...   ...  ...  ...             ...        ...          ...
# 710         710  1000  0.1  0.6        1.002990   4.850008    16.716508
# 711         711  1000  0.1  0.7        1.001744   4.591365    14.310626
# 712         712  1000  0.1  0.8        1.011660   4.378456    12.645755
# 713         713  1000  0.1  0.9        1.003500   4.171935    11.149997
# 714         714  1000  0.1  1.0        1.003856   4.006514    10.038559
#
#       mean_n_het  mean_n_homo     ns  selective_deaths
# 0    2053.955184  1026.652397    0.0          0.000000
# 1    2025.218207  1026.782649    0.0          0.000000
# 2    1952.405117   972.987745    0.0          0.000000
# 3    1983.190407   996.496804    0.0          0.000000
# 4    1939.110448   954.638309    0.0          0.000000
# ..           ...          ...    ...               ...
# 710    16.652649     0.031929  100.0          1.002352
# 711    14.264966     0.022829  100.0          1.000831
# 712    12.610231     0.017763  100.0          1.010595
# 713    11.123135     0.013431  100.0          1.002425
# 714    10.017086     0.010736  100.0          1.002782
#
# [715 rows x 11 columns]

# %%
# Set a custom color palette
palette = sns.color_palette("husl", len(df['h'].unique()))

# Create the FacetGrid with the custom palette
g = sns.FacetGrid(df, col="h", col_wrap=3, height=4, palette=palette)
g.map(sns.lineplot, 'ns', 'selective_deaths')
g.map(sns.scatterplot, 'ns', 'selective_deaths', s=50, color=".3", edgecolor="w")

# Customize titles and labels
g.set_titles(col_template="h = {col_name}")
g.set_axis_labels("ns", "selective_deaths")

# Set x-axis limits
g.set(xlim=(-1, 102
))



# Add a title to the entire plot
plt.subplots_adjust(top=0.9)
g.fig.suptitle('selective_deaths vs ns for different values of h', fontsize=16)

# Show the plot
plt.show()

# %%
# Set a custom color palette
palette = sns.color_palette("husl", len(df['h'].unique()))

# Create the FacetGrid with the custom palette
g = sns.FacetGrid(df, col="h", col_wrap=3, height=4, palette=palette)
g.map(sns.lineplot, 'ns', 'selective_deaths')
g.map(sns.scatterplot, 'ns', 'selective_deaths', s=50, color=".3", edgecolor="w")

# Customize titles and labels
g.set_titles(col_template="h = {col_name}")
g.set_axis_labels("ns", "selective_deaths")

# Set x-axis limits
g.set(xlim=(0, 10))



# Add a title to the entire plot
plt.subplots_adjust(top=0.9)
g.fig.suptitle('selective_deaths vs ns for different values of h', fontsize=16)

# Show the plot
plt.show()

# %%
# Set a custom color palette
palette = sns.color_palette("husl", len(df['h'].unique()))

# Create the FacetGrid with the custom palette
g = sns.FacetGrid(df, col="h", col_wrap=3, height=4, palette=palette)
g.map(sns.lineplot, 'ns', 'mean_t')
g.map(sns.scatterplot, 'ns', 'mean_t', s=50, color=".3", edgecolor="w")

# Customize titles and labels
g.set_titles(col_template="h = {col_name}")
g.set_axis_labels("ns", "mean_t")

# Set x-axis limits
g.set(xlim=(0, 100))



# Add a title to the entire plot
plt.subplots_adjust(top=0.9)
g.fig.suptitle('mean_t vs ns for different values of h', fontsize=16)

# Show the plot
plt.show()

# %%
# Set a custom color palette
palette = sns.color_palette("husl", len(df['h'].unique()))

# Create the FacetGrid with the custom palette
g = sns.FacetGrid(df, col="h", col_wrap=3, height=4, palette=palette)
g.map(sns.lineplot, 'ns', 'mean_t')
g.map(sns.scatterplot, 'ns', 'mean_t', s=50, color=".3", edgecolor="w")

# Customize titles and labels
g.set_titles(col_template="h = {col_name}")
g.set_axis_labels("ns", "mean_t")

# Set x-axis limits
g.set(xlim=(0, 10))



# Add a title to the entire plot
plt.subplots_adjust(top=0.9)
g.fig.suptitle('mean_t vs ns for different values of h', fontsize=16)

# Show the plot
plt.show()

# %%
# Set a custom color palette
palette = sns.color_palette("husl", len(df['h'].unique()))

# Create the FacetGrid with the custom palette
g = sns.FacetGrid(df, col="h", col_wrap=3, height=4, palette=palette)
g.map(sns.lineplot, 'ns', 'mean_count')
g.map(sns.scatterplot, 'ns', 'mean_count', s=50, color=".3", edgecolor="w")

# Customize titles and labels
g.set_titles(col_template="h = {col_name}")
g.set_axis_labels("ns", "mean_count")

# Set x-axis limits
g.set(xlim=(0, 100))



# Add a title to the entire plot
plt.subplots_adjust(top=0.9)
g.fig.suptitle('mean_count vs ns for different values of h', fontsize=16)

# Show the plot
plt.show()

# %%
# Set a custom color palette
palette = sns.color_palette("husl", len(df['h'].unique()))

# Create the FacetGrid with the custom palette
g = sns.FacetGrid(df, col="h", col_wrap=3, height=4, palette=palette)
g.map(sns.lineplot, 'ns', 'mean_count')
g.map(sns.scatterplot, 'ns', 'mean_count', s=50, color=".3", edgecolor="w")

# Customize titles and labels
g.set_titles(col_template="h = {col_name}")
g.set_axis_labels("ns", "mean_count")

# Set x-axis limits
g.set(xlim=(0, 10))



# Add a title to the entire plot
plt.subplots_adjust(top=0.9)
g.fig.suptitle('mean_count vs ns for different values of h', fontsize=16)

# Show the plot
plt.show()

# %%
# Set a custom color palette
palette = sns.color_palette("husl", len(df['h'].unique()))

# Create the FacetGrid with the custom palette
g = sns.FacetGrid(df, col="h", col_wrap=3, height=4, palette=palette)
g.map(sns.lineplot, 'ns', 'mean_count', color='black', label='mean_count')
g.map(sns.scatterplot, 'ns', 'mean_count', s=50, color="black", edgecolor="w")

g.map(sns.lineplot, 'ns', 'mean_n_homo', color='blue', label='mean_n_homo')
g.map(sns.scatterplot, 'ns', 'mean_n_homo', s=50, color='blue', edgecolor="w")
g.map(sns.lineplot, 'ns', 'mean_n_het', color='red', label='mean_n_het')
g.map(sns.scatterplot, 'ns', 'mean_n_het', s=50, color='red', edgecolor="w")

# Customize titles and labels
g.set_titles(col_template="h = {col_name}")
g.set_axis_labels("ns", "mean_count")

# Set x-axis limits
g.set(xlim=(0, 10))

# Add a title to the entire plot
plt.subplots_adjust(top=0.9)
g.fig.suptitle('mean_count vs ns for different values of h', fontsize=16)

# Add a legend
g.add_legend()

# Show the plot
plt.show()
