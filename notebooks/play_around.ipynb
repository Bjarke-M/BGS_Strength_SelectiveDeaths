# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../results/selected_deaths/summaries/mean_results.csv')

# %%
df['ns'] = df['n'] * df['s']

# %%
df
# Out:
#      Unnamed: 0     n         s    h  mean_count_s_h     mean_t   mean_count  \
# 0             0  1000  0.000001  0.1        0.000406  14.558796  4060.215665
# 1             1  1000  0.000001  0.2        0.000813  14.678514  4062.897555
# 2             2  1000  0.000001  0.3        0.001184  14.557809  3946.289963
# 3             3  1000  0.000001  0.4        0.001558  14.550986  3895.850808
# 4             4  1000  0.000001  0.5        0.001952  14.564624  3904.744870
# ..          ...   ...       ...  ...             ...        ...          ...
# 635         635  1000  0.100000  0.6        1.005744   4.856598    16.762394
# 636         636  1000  0.100000  0.7        1.005479   4.595592    14.363990
# 637         637  1000  0.100000  0.8        1.006112   4.371282    12.576401
# 638         638  1000  0.100000  0.9        1.007268   4.179883    11.191866
# 639         639  1000  0.100000  1.0        1.003189   4.002552    10.031894
#
#           ns
# 0      0.001
# 1      0.001
# ...

# %%
# Set a custom color palette
palette = sns.color_palette("husl", len(df['h'].unique()))

# Create the FacetGrid with the custom palette
g = sns.FacetGrid(df, col="h", col_wrap=3, height=4, palette=palette)
g.map(sns.lineplot, 'ns', 'mean_count_s_h')
g.map(sns.scatterplot, 'ns', 'mean_count_s_h', s=50, color=".3", edgecolor="w")

# Customize titles and labels
g.set_titles(col_template="h = {col_name}")
g.set_axis_labels("ns", "mean_count_s_h")

# Set x-axis limits
g.set(xlim=(-1, 102
))



# Add a title to the entire plot
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Mean Count*s*h vs ns for different values of h', fontsize=16)

# Show the plot
plt.show()

# %%
# Set a custom color palette
palette = sns.color_palette("husl", len(df['h'].unique()))

# Create the FacetGrid with the custom palette
g = sns.FacetGrid(df, col="h", col_wrap=3, height=4, palette=palette)
g.map(sns.lineplot, 'ns', 'mean_count_s_h')
g.map(sns.scatterplot, 'ns', 'mean_count_s_h', s=50, color=".3", edgecolor="w")

# Customize titles and labels
g.set_titles(col_template="h = {col_name}")
g.set_axis_labels("ns", "mean_count_s_h")

# Set x-axis limits
g.set(xlim=(0, 10))



# Add a title to the entire plot
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Count_s_h vs ns for different values of h', fontsize=16)

# Show the plot
plt.show()

# %%
# Set a custom color palette
palette = sns.color_palette("husl", len(df['h'].unique()))

# Create the FacetGrid with the custom palette
g = sns.FacetGrid(df, col="h", col_wrap=3, height=4, palette=palette)
g.map(sns.lineplot, 'ns', 'mean_t')
g.map(sns.scatterplot, 'ns', 'mean_t', s=50, color=".3", edgecolor="w")

# Customize titles and labels
g.set_titles(col_template="h = {col_name}")
g.set_axis_labels("ns", "mean_t")

# Set x-axis limits
g.set(xlim=(0, 100))



# Add a title to the entire plot
plt.subplots_adjust(top=0.9)
g.fig.suptitle('mean_t vs ns for different values of h', fontsize=16)

# Show the plot
plt.show()

# %%
# Set a custom color palette
palette = sns.color_palette("husl", len(df['h'].unique()))

# Create the FacetGrid with the custom palette
g = sns.FacetGrid(df, col="h", col_wrap=3, height=4, palette=palette)
g.map(sns.lineplot, 'ns', 'mean_t')
g.map(sns.scatterplot, 'ns', 'mean_t', s=50, color=".3", edgecolor="w")

# Customize titles and labels
g.set_titles(col_template="h = {col_name}")
g.set_axis_labels("ns", "mean_t")

# Set x-axis limits
g.set(xlim=(0, 10))



# Add a title to the entire plot
plt.subplots_adjust(top=0.9)
g.fig.suptitle('mean_t vs ns for different values of h', fontsize=16)

# Show the plot
plt.show()

# %%
# Set a custom color palette
palette = sns.color_palette("husl", len(df['h'].unique()))

# Create the FacetGrid with the custom palette
g = sns.FacetGrid(df, col="h", col_wrap=3, height=4, palette=palette)
g.map(sns.lineplot, 'ns', 'mean_count')
g.map(sns.scatterplot, 'ns', 'mean_count', s=50, color=".3", edgecolor="w")

# Customize titles and labels
g.set_titles(col_template="h = {col_name}")
g.set_axis_labels("ns", "mean_count")

# Set x-axis limits
g.set(xlim=(0, 100))



# Add a title to the entire plot
plt.subplots_adjust(top=0.9)
g.fig.suptitle('mean_count vs ns for different values of h', fontsize=16)

# Show the plot
plt.show()

# %%
# Set a custom color palette
palette = sns.color_palette("husl", len(df['h'].unique()))

# Create the FacetGrid with the custom palette
g = sns.FacetGrid(df, col="h", col_wrap=3, height=4, palette=palette)
g.map(sns.lineplot, 'ns', 'mean_count')
g.map(sns.scatterplot, 'ns', 'mean_count', s=50, color=".3", edgecolor="w")

# Customize titles and labels
g.set_titles(col_template="h = {col_name}")
g.set_axis_labels("ns", "mean_count")

# Set x-axis limits
g.set(xlim=(0, 10))



# Add a title to the entire plot
plt.subplots_adjust(top=0.9)
g.fig.suptitle('mean_count vs ns for different values of h', fontsize=16)

# Show the plot
plt.show()

# %%
ns40 = pd.read_csv('../results/selected_deaths/summaries/popsize_1000_ns_40_dominance_0.8.csv')

# %%
ns40
# Out:
#          count    h     n     s  t
# 0            1  0.8  1000  0.04  1
# 1            4  0.8  1000  0.04  4
# 2            1  0.8  1000  0.04  1
# 3            1  0.8  1000  0.04  1
# 4            2  0.8  1000  0.04  2
# ...        ...  ...   ...   ... ..
# 1999995      1  0.8  1000  0.04  1
# 1999996      1  0.8  1000  0.04  1
# 1999997      1  0.8  1000  0.04  1
# 1999998      1  0.8  1000  0.04  1
# 1999999      1  0.8  1000  0.04  1
#
# [2000000 rows x 5 columns]

# %%
plt.figure(figsize=(10, 6))
sns.histplot(np.log10(ns40['count']*ns40['s']*ns40['h']), bins=30)
plt.title('Distribution of Count*s*h at ns=40 (log10 scale)')
plt.xlabel('Log10 Count*s*h')
plt.ylabel('Frequency')
plt.show()
